# %%
import numpy as np
import pandas as pd
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
def load_dataset(filename):
    return pd.read_csv(filename)

def query_probability_iris(dataset, variable, evidence):
    evidence_columns = list(evidence.keys())
    evidence_values = list(evidence.values())

    # Filter the dataset based on evidence
    filtered_data = dataset.copy()
    for column, value in zip(evidence_columns, evidence_values):
        filtered_data = filtered_data[filtered_data[column] > value]

    # Calculate the probability distribution of the variable given the evidence
    probabilities = filtered_data[variable].value_counts(normalize=True)
    return probabilities

def calculate_accuracy(predictions, actual):
    correct_predictions = np.sum(predictions == actual)
    total_samples = len(actual)
    accuracy = (correct_predictions / total_samples) * 100
    return accuracy

# Load the heart disease dataset
heartDisease = load_dataset('/content/drive/MyDrive/A_ML_LAB/5_BAYESIAN NETWORK/heart.csv')
heartDisease = heartDisease.replace('?', np.nan)

print('Sample instances from the heart disease dataset are given below')
print(heartDisease.head())

print('\nAttributes and datatypes of the heart disease dataset')
print(heartDisease.dtypes)

print('\nInferencing with Bayesian Network:')
print('\n1. Probability of Heart Disease given evidence: restecg = 1')
q1 = query_probability_iris(heartDisease, 'heartdisease', {'restecg': 1})
print(q1)


# Input real-time values for predicted and actual values
predicted_values = [...]  # Provide the predicted values in a list
actual_values = [...]  # Provide the actual values in a list

accuracy = calculate_accuracy(predicted_values, actual_values)
print('Accuracy:', accuracy, '%')
# Out:
# Sample instances from the heart disease dataset are given below
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#   ca thal  heartdisease
# 0  0    6             0
# 1  3    3             2
# 2  2    7             1
# 3  0    3             0
# 4  0    3             0
#
# Attributes and datatypes of the heart disease dataset
# age               int64
# sex               int64
# cp                int64
# trestbps          int64
# chol              int64
# fbs               int64
# restecg           int64
# thalach           int64
# exang             int64
# ...

# %%
# Load the iris dataset
iris = load_dataset('/content/drive/MyDrive/A_ML_LAB/5_BAYESIAN NETWORK/iris.csv')

print('\nSample instances from the iris dataset are given below')
print(iris.head())

print('\nAttributes and datatypes of the iris dataset')
print(iris.dtypes)

print('\nInferencing with Bayesian Network:')
print('\n2. Probability of Iris species given evidence: petal length (cm) > 3 and petal width (cm) > 1')
q2 = query_probability_iris(iris, 'target', {'petal length (cm)': 3, 'petal width (cm)': 1})
print(q2)

# Input real-time values for predicted and actual values
predicted_species = [...]  # Provide the predicted species in a list
actual_species = [...]  # Provide the actual species in a list

accuracy = calculate_accuracy(predicted_species, actual_species)
print('Accuracy:', accuracy, '%')
# Out:
# Sample instances from the iris dataset are given below
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#
# Attributes and datatypes of the iris dataset
# sepal length (cm)    float64
# sepal width (cm)     float64
# petal length (cm)    float64
# petal width (cm)     float64
# target                 int64
# dtype: object
#
# Inferencing with Bayesian Network:
#
# 2. Probability of Iris species given evidence: petal length (cm) > 3 and petal width (cm) > 1
# 2    0.543478
# 1    0.456522
# ...

# %% [markdown]
# IMA

# %%
import numpy as np
import pandas as pd

heartDisease = pd.read_csv('/content/drive/MyDrive/A_ML_LAB/5_BAYESIAN NETWORK/heart.csv')
heartDisease = heartDisease.replace('?', np.nan)

print('Sample instances from the dataset are given below')
print(heartDisease.head())

print('\nAttributes and datatypes')
print(heartDisease.dtypes)

def query_probability(variable, evidence):
    evidence_columns = list(evidence.keys())
    evidence_values = list(evidence.values())

    # Filter the dataset based on evidence
    filtered_data = heartDisease.copy()
    for column, value in zip(evidence_columns, evidence_values):
        filtered_data = filtered_data[filtered_data[column] == value]

    # Calculate the probability distribution of the variable given the evidence
    probabilities = filtered_data[variable].value_counts(normalize=True)
    return probabilities

def calculate_accuracy(predictions, actual):
    correct_predictions = np.sum(predictions == actual)
    total_samples = len(actual)
    accuracy = (correct_predictions / total_samples) * 100
    return accuracy

print('\nInferencing with Bayesian Network:')
print('\n1. Probability of HeartDisease given evidence= restecg')
q1 = query_probability('heartdisease', {'restecg': 1})
print(q1)

# Input real-time values for predicted and actual values
predicted_values = [...]  # Provide the predicted values in a list
actual_values = [...]  # Provide the actual values in a list

accuracy = calculate_accuracy(predicted_values, actual_values)
print('Accuracy:', accuracy, '%')
# Out:
# Sample instances from the dataset are given below
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#   ca thal  heartdisease
# 0  0    6             0
# 1  3    3             2
# 2  2    7             1
# 3  0    3             0
# 4  0    3             0
#
# Attributes and datatypes
# age               int64
# sex               int64
# cp                int64
# trestbps          int64
# chol              int64
# fbs               int64
# restecg           int64
# thalach           int64
# exang             int64
# oldpeak         float64
# ...
